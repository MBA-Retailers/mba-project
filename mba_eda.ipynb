# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Read the CSV file
df = pd.read_csv('Dataset_1.csv',sep=';')
# Out:
# /var/folders/d3/mb3yqvls6894k9653zg1_86m0000gp/T/ipykernel_20147/1510816363.py:2: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('Dataset_1.csv',sep=';')

# %%
# Print the head of the dataset
print(df.head())
# Out:
#    BillNo                             Itemname  Quantity              Date  \
# 0  536365   WHITE HANGING HEART T-LIGHT HOLDER         6  01.12.2010 08:26
# 1  536365                  WHITE METAL LANTERN         6  01.12.2010 08:26
# 2  536365       CREAM CUPID HEARTS COAT HANGER         8  01.12.2010 08:26
# 3  536365  KNITTED UNION FLAG HOT WATER BOTTLE         6  01.12.2010 08:26
# 4  536365       RED WOOLLY HOTTIE WHITE HEART.         6  01.12.2010 08:26
#
#   Price  CustomerID         Country
# 0  2,55     17850.0  United Kingdom
# 1  3,39     17850.0  United Kingdom
# 2  2,75     17850.0  United Kingdom
# 3  3,39     17850.0  United Kingdom
# 4  3,39     17850.0  United Kingdom

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 522064 entries, 0 to 522063
# Data columns (total 7 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   BillNo      522064 non-null  object
#  1   Itemname    520609 non-null  object
#  2   Quantity    522064 non-null  int64
#  3   Date        522064 non-null  object
#  4   Price       522064 non-null  object
#  5   CustomerID  388023 non-null  float64
#  6   Country     522064 non-null  object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 27.9+ MB

# %%
df['unique_count'] = df.nunique(axis=1)
df.head()
# Out:
#    BillNo                             Itemname  Quantity              Date  \
# 0  536365   WHITE HANGING HEART T-LIGHT HOLDER         6  01.12.2010 08:26
# 1  536365                  WHITE METAL LANTERN         6  01.12.2010 08:26
# 2  536365       CREAM CUPID HEARTS COAT HANGER         8  01.12.2010 08:26
# 3  536365  KNITTED UNION FLAG HOT WATER BOTTLE         6  01.12.2010 08:26
# 4  536365       RED WOOLLY HOTTIE WHITE HEART.         6  01.12.2010 08:26
#
#   Price  CustomerID         Country  unique_count
# 0  2,55     17850.0  United Kingdom             7
# 1  3,39     17850.0  United Kingdom             7
# 2  2,75     17850.0  United Kingdom             7
# 3  3,39     17850.0  United Kingdom             7
# 4  3,39     17850.0  United Kingdom             7

# %%
# Get summary statistics
summary_stats = df.describe()
print(summary_stats)
# Out:
#             Quantity     CustomerID   unique_count
# count  522064.000000  388023.000000  522064.000000
# mean       10.090435   15316.931710       6.740461
# std       161.110525    1721.846964       0.444694
# min     -9600.000000   12346.000000       5.000000
# 25%         1.000000   13950.000000       6.000000
# 50%         3.000000   15265.000000       7.000000
# 75%        10.000000   16837.000000       7.000000
# max     80995.000000   18287.000000       7.000000

# %%
df['Price'] = pd.to_numeric(df['Price'], errors='coerce')

df.plot(x='BillNo', y='Price')
# Out:
# <Axes: xlabel='BillNo'>

# %%
df['Country'].value_counts().plot(kind='bar')
plt.xlabel('Country')
plt.ylabel('Count')
plt.title('Number of Unique Entries for Each Country')
plt.show()
